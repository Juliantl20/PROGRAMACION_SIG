# %%
getwd()
list.files()
list.files(recursive = TRUE)
# Out:
# [1] "/home/rstudio/work/PRACTICA_2"
# [1] "TALLER_2_files" "TALLER_2.html"  "Taller_2.ipynb" "TALLER_2.pdf"
# [5] "TALLER_2.qmd"   "Untitled.ipynb"
#  [1] "TALLER_2_files/libs/bootstrap/bootstrap-9e3ffae467580fdb927a41352e75a2e0.min.css"
#  [2] "TALLER_2_files/libs/bootstrap/bootstrap-icons.css"
#  [3] "TALLER_2_files/libs/bootstrap/bootstrap-icons.woff"
#  [4] "TALLER_2_files/libs/bootstrap/bootstrap.min.js"
#  [5] "TALLER_2_files/libs/clipboard/clipboard.min.js"
#  [6] "TALLER_2_files/libs/quarto-html/anchor.min.js"
#  [7] "TALLER_2_files/libs/quarto-html/axe/axe-check.js"
#  [8] "TALLER_2_files/libs/quarto-html/popper.min.js"
#  [9] "TALLER_2_files/libs/quarto-html/quarto-syntax-highlighting-ed96de9b727972fe78a7b5d16c58bf87.css"
# [10] "TALLER_2_files/libs/quarto-html/quarto.js"
# [11] "TALLER_2_files/libs/quarto-html/tabsets/tabsets.js"
# [12] "TALLER_2_files/libs/quarto-html/tippy.css"
# [13] "TALLER_2_files/libs/quarto-html/tippy.umd.min.js"
# [14] "TALLER_2.html"
# ...

# %%
# #| include: false
source("D:/MAESTRIA/PROGRAMACION_SIG/juatorreslo/PRACTICA_2/docs/j_eval_j_plot.r")
# Out:
# Warning message in file(filename, "r", encoding = encoding):
# “cannot open file 'D:/MAESTRIA/PROGRAMACION_SIG/juatorreslo/PRACTICA_2/docs/j_eval_j_plot.r': No such file or directory”
# Error in file(filename, "r", encoding = encoding): cannot open the connection
# Traceback:
#
# 1. file(filename, "r", encoding = encoding)
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "cannot open the connection", base::quote(file(filename, "r",
#  .     encoding = encoding)))
